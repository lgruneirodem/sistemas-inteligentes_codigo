# %% [markdown]
# <ul>
#   <li>El Mundo (https://elmundo.es) </li>
#     <ul>
#         <li>Salud: https://www.elmundo.es/ciencia-y-salud/salud.html </li>
#         <li>Tecnología: https://www.elmundo.es/tecnologia.html  </li>
#         <li>Ciencia: https://www.elmundo.es/ciencia-y-salud/ciencia.html</li>
#     </ul>
#   <li>El País (https://elpais.com/)</li>
#     <ul>
#         <li>Sanidad: https://elpais.com/noticias/sanidad/ </li>
#         <li>Tecnología: https://elpais.com/tecnologia/</li>
#         <li> Ciencia: https://elpais.com/ciencia/</li>
#     </ul>
#   <li>20 Minutos (https://www.20minutos.es/) </li>
#     <ul>
#         <li>Salud: https://www.20minutos.es/salud/ </li>
#         <li>Tecnología: https://www.20minutos.es/tecnologia/ </li>
#         <li>Ciencia: https://www.20minutos.es/ciencia/ </li>
#     </ul>
#
# </ul>

# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
# El Pais

diario = "https://elpais.com"
diario_texto = "elPais"
counter_dictionary = {}

def elPaisPalabrasLlaves(soup):
    palabras_llaves = ""
    separador = ", "
    # Hacemos un lista con las palabras llave
    html_llaves = soup.find("ul", class_="_df _ls")
    # Solo extraemos los enlaces
    enlaces_llaves = html_llaves.find_all("a")
    # Sacamos el texto de los enlaces y y lo añadimos a la lista 
    for enlace in enlaces_llaves:
        palabras_llaves = palabras_llaves + enlace.text + separador
    # Quitamos el ultimo separador
    palabras_llaves = palabras_llaves[:-(len(separador))]
    return palabras_llaves

def elPaisTexto(soup):
    content = ""
    # div con todo el texto
    text = soup.find("div", class_="a_c")
    # buscar todos los p
    paragraphs = text.find_all("p")
    # Sacamos el contenido de p y lo añadimos a content
    for paragraph in paragraphs:
        content = content + paragraph.text + "\n"
    # print(content)
    return content

def elPaisTitulo(soup):
    return soup.find("h1", class_="a_t").text

def elPaisEntradilla(soup):
    return soup.find("h2", class_="a_st").text

def elPaisFecha(soup):
    date_length = 10 # 2021-12-03T18:09:39.529Z
    return soup.find("a", id="article_date_p")["data-date"][:date_length]

def guardarFichero(contenido, fecha, diario_texto, categoria):
    # calcular numero (nnn)
    counter = 1
    if fecha in counter_dictionary[categoria]:
        counter = counter_dictionary[categoria][fecha]
        counter_dictionary[categoria][fecha] += 1
    else:
        counter_dictionary[categoria][fecha] = 2
    
    # /diario/categoria/categoria.fecha.nnn.txt
    abs_path = os.getcwd()
    rel_path =  diario_texto + "/" + categoria + "/"
    nombre_fichero = diario_texto + "." + categoria + "." + fecha + "." + str(counter).zfill(3) + ".txt"
    path = os.path.join(abs_path, rel_path, nombre_fichero)
    try:
        with open(path, 'x') as fichero:
            fichero.write(contenido)
        print ("File " + nombre_fichero + " created!")
    except IOError:
        print("File " + nombre_fichero + " already exists...")


def elPaisWebScraping(pagina, diario_texto, categoria):
    soup = BeautifulSoup(pagina, 'html.parser')

    palabras_llaves = elPaisPalabrasLlaves(soup)
    titulo = elPaisTitulo(soup)
    entradilla = elPaisEntradilla(soup)
    texto = elPaisTexto(soup)
    fecha = elPaisFecha(soup)

    content = palabras_llaves + "\n\n" + titulo + "\n\n" + entradilla + "\n\n" + texto
    guardarFichero(content,fecha,diario_texto, categoria)
    return content

def elPais(diario, diario_texto, categoria, url):
    counter_dictionary[categoria] = {}
    pagina = requests.get(url)
    soup = BeautifulSoup(pagina.content, 'html.parser')

    # sacar todas los enlaces de los articulos de la pagina categorial
    enlaces = []
    for article in soup.find_all("article"):
        enlaces.append(diario + article.find("a")['href'])

    # processar cada articulo
    for enlace in enlaces: 
        articulo = requests.get(enlace)
        try:
            elPaisWebScraping(articulo.content, diario_texto, categoria)
        except:
            print("Error procesando articulo, saltando el articulo " + enlace)



# processar las categorias: salud, ciencia y tecnologia
categoria = "salud"
url = diario + "/noticias/sanidad/"
elPais(diario, diario_texto, categoria, url)

categoria = "ciencia"
url = diario + "/ciencia/"
elPais(diario, diario_texto, categoria, url)

categoria = "tecnologia"
url = diario + "/tecnologia/"
elPais(diario, diario_texto, categoria, url)

categoria = "odio"
url = diario + "/noticias/delitos-odio/"
elPais(diario, diario_texto, categoria, url)
# Out:
# File elPais.salud.2022-01-22.001.txt created!
# File elPais.salud.2022-01-22.002.txt created!
# File elPais.salud.2022-01-22.003.txt created!
# File elPais.salud.2022-01-21.001.txt created!
# File elPais.salud.2022-01-21.002.txt created!
# File elPais.salud.2022-01-21.003.txt created!
# File elPais.salud.2022-01-21.004.txt created!
# File elPais.salud.2022-01-21.005.txt created!
# File elPais.salud.2022-01-21.006.txt created!
# File elPais.salud.2022-01-21.007.txt created!
# File elPais.salud.2022-01-21.008.txt created!
# File elPais.salud.2022-01-20.001.txt created!
# File elPais.salud.2022-01-20.002.txt created!
# File elPais.salud.2022-01-20.003.txt created!
# File elPais.salud.2022-01-20.004.txt created!
# File elPais.salud.2022-01-20.005.txt created!
# File elPais.salud.2022-01-20.006.txt created!
# File elPais.salud.2022-01-20.007.txt created!
# File elPais.salud.2022-01-20.008.txt created!
# File elPais.salud.2022-01-19.001.txt created!
# File elPais.salud.2022-01-19.002.txt created!
# File elPais.salud.2022-01-19.003.txt created!
# File elPais.salud.2022-01-19.004.txt created!
# File elPais.salud.2022-01-19.005.txt created!
# File elPais.salud.2022-01-19.006.txt created!
# File elPais.salud.2022-01-19.007.txt created!
# File elPais.salud.2022-01-19.008.txt created!
# File elPais.ciencia.2022-01-22.001.txt created!
# File elPais.ciencia.2022-01-21.001.txt created!
# File elPais.ciencia.2022-01-20.001.txt created!
# File elPais.ciencia.2022-01-05.001.txt created!
# File elPais.ciencia.2021-12-21.001.txt created!
# File elPais.ciencia.2021-12-15.001.txt created!
# File elPais.ciencia.2021-12-10.001.txt created!
# File elPais.ciencia.2022-01-21.002.txt created!
# File elPais.ciencia.2022-01-20.002.txt created!
# File elPais.ciencia.2022-01-20.003.txt created!
# File elPais.ciencia.2022-01-20.004.txt created!
# File elPais.ciencia.2022-01-19.001.txt created!
# File elPais.ciencia.2022-01-19.002.txt created!
# File elPais.ciencia.2022-01-19.003.txt created!
# File elPais.ciencia.2022-01-21.003.txt created!
# File elPais.ciencia.2022-01-18.001.txt created!
# File elPais.ciencia.2022-01-21.004.txt created!
# File elPais.ciencia.2022-01-17.001.txt created!
# File elPais.ciencia.2022-01-17.002.txt created!
# File elPais.ciencia.2022-01-22.002.txt created!
# File elPais.ciencia.2022-01-12.001.txt created!
# File elPais.ciencia.2022-01-06.001.txt created!
# File elPais.ciencia.2021-12-17.001.txt created!
# File elPais.ciencia.2022-01-14.001.txt created!
# File elPais.ciencia.2022-01-07.001.txt created!
# File elPais.ciencia.2021-12-31.001.txt created!
# File elPais.ciencia.2022-01-20.005.txt created!
# File elPais.ciencia.2022-01-13.001.txt created!
# File elPais.ciencia.2022-01-06.002.txt created!
# File elPais.ciencia.2021-12-30.001.txt created!
# File elPais.ciencia.2021-12-23.001.txt created!
# File elPais.ciencia.2022-01-19.004.txt created!
# File elPais.ciencia.2022-01-12.002.txt created!
# File elPais.ciencia.2022-01-04.001.txt created!
# File elPais.ciencia.2021-12-29.001.txt created!
# File elPais.ciencia.2021-12-21.002.txt created!
# File elPais.ciencia.2021-10-14.001.txt created!
# File elPais.ciencia.2021-08-06.001.txt created!
# File elPais.ciencia.2021-07-12.001.txt created!
# File elPais.ciencia.2021-03-01.001.txt created!
# File elPais.tecnologia.2022-01-22.001.txt created!
# File elPais.tecnologia.2022-01-22.002.txt created!
# File elPais.tecnologia.2022-01-21.001.txt created!
# File elPais.tecnologia.2022-01-22.003.txt created!
# File elPais.tecnologia.2022-01-20.001.txt created!
# File elPais.tecnologia.2022-01-21.002.txt created!
# File elPais.tecnologia.2022-01-19.001.txt created!
# File elPais.tecnologia.2022-01-20.002.txt created!
# File elPais.tecnologia.2022-01-20.003.txt created!
# File elPais.tecnologia.2022-01-18.001.txt created!
# File elPais.tecnologia.2022-01-19.002.txt created!
# File elPais.tecnologia.2022-01-18.002.txt created!
# File elPais.tecnologia.2022-01-18.003.txt created!
# File elPais.tecnologia.2022-01-18.004.txt created!
# File elPais.tecnologia.2022-01-16.001.txt created!
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/2021/12/21/actualidad/1640085867_742393.html
# File elPais.tecnologia.2021-12-01.001.txt created!
# File elPais.tecnologia.2021-11-29.001.txt created!
# File elPais.tecnologia.2021-11-26.001.txt created!
# File elPais.tecnologia.2021-11-24.001.txt created!
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/con-proposito/2021-12-07/pequenas-pero-seguras-como-las-pymes-estan-blindando-los-telefonos-de-empresa.html
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/con-proposito/2021-12-01/asi-es-la-luz-del-invierno-en-los-rincones-mas-bonitos.html
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/5g-el-futuro-es-ahora/2021-12-17/el-reto-tecno-de-la-espana-rural-de-vivir-sin-cobertura-al-tractor-autonomo.html
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/5g-el-futuro-es-ahora/2021-11-20/el-5g-lleva-los-videojuegos-a-la-siguiente-pantalla.html
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/radar-pyme/2021-11-29/plasticos-del-mar-para-fabricar-muebles-y-coches-movidos-por-hidrogeno-algunas-ideas-para-descarbonizar-nuestra-vida.html
# Error procesando articulo, saltando el articulo https://elpais.com/tecnologia/radar-pyme/2021-11-04/objetivo-salvar-el-planeta-sin-dejar-atras-a-las-personas.html
# File elPais.tecnologia.2021-12-13.001.txt created!
# File elPais.tecnologia.2021-12-14.001.txt created!
# File elPais.tecnologia.2021-12-03.001.txt created!
# File elPais.tecnologia.2021-11-30.001.txt created!
# File elPais.odio.2022-01-21.001.txt already exists...
# File elPais.odio.2022-01-20.001.txt already exists...
# File elPais.odio.2022-01-17.001.txt already exists...
# File elPais.odio.2022-01-12.001.txt already exists...
# File elPais.odio.2022-01-01.001.txt already exists...
# Error procesando articulo, saltando el articulo https://elpais.com/elpais/2021/12/26/album/1640503548_165051.html
# File elPais.odio.2021-12-07.001.txt already exists...
# File elPais.odio.2021-12-06.001.txt already exists...
# File elPais.odio.2021-12-06.002.txt already exists...
# File elPais.odio.2021-12-03.001.txt already exists...
# File elPais.odio.2021-12-01.001.txt already exists...
# File elPais.odio.2021-11-30.001.txt already exists...
# File elPais.odio.2021-11-23.001.txt already exists...
# File elPais.odio.2021-11-18.001.txt already exists...
# File elPais.odio.2021-11-16.001.txt already exists...
# File elPais.odio.2021-11-15.001.txt already exists...
# File elPais.odio.2021-11-14.001.txt already exists...
# File elPais.odio.2021-11-08.001.txt already exists...
# File elPais.odio.2021-11-08.002.txt already exists...
# File elPais.odio.2021-10-29.001.txt already exists...
# File elPais.odio.2021-10-28.001.txt already exists...
# File elPais.odio.2021-10-25.001.txt already exists...
# File elPais.odio.2021-10-23.001.txt already exists...
# File elPais.odio.2021-10-08.001.txt already exists...
# File elPais.odio.2021-10-05.001.txt already exists...
# File elPais.odio.2021-10-04.001.txt already exists...
# File elPais.odio.2021-09-27.001.txt already exists...
